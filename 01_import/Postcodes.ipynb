# %%
import numpy as np
from numpy import savetxt
import pandas as pd
import datetime
import os
import glob
import json
import csv

# %%
data = pd.read_csv('certificates.csv')
# Out:
# C:\Users\KingRemy\AppData\Local\Temp\ipykernel_38680\667726140.py:1: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('certificates.csv')

# %%
data.head()
# Out:
#                               LMK_KEY              ADDRESS1    ADDRESS2  \
# 0  1225531369222014102221521799828174      7, Enstone Court         NaN
# 1   790669781812012052109391995220690      3, Beasley Place         NaN
# 2   367642649152009092114161306210960    123, Church Street  Silverdale
# 3  1275322199062017121112172682288793         1, Springpool       Keele
# 4   572596109062010120713525022138790  21, St. Martins Road  Talke Pits
#
#   ADDRESS3 POSTCODE  BUILDING_REFERENCE_NUMBER CURRENT_ENERGY_RATING  \
# 0      NaN  ST5 4JE                 7958629278                     C
# 1      NaN  ST5 7PF                 6098158968                     B
# 2      NaN  ST5 6JJ                 9040967668                     E
# 3      NaN  ST5 5BN                 9847952378                     C
# 4      NaN  ST7 1QS                 9276022868                     D
#
#   POTENTIAL_ENERGY_RATING  CURRENT_ENERGY_EFFICIENCY  \
# 0                       B                         69
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42196 entries, 0 to 42195
# Data columns (total 92 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   LMK_KEY                        42196 non-null  object
#  1   ADDRESS1                       42196 non-null  object
#  2   ADDRESS2                       21637 non-null  object
#  3   ADDRESS3                       3427 non-null   object
#  4   POSTCODE                       42196 non-null  object
#  5   BUILDING_REFERENCE_NUMBER      42196 non-null  int64
#  6   CURRENT_ENERGY_RATING          42196 non-null  object
#  7   POTENTIAL_ENERGY_RATING        42196 non-null  object
#  8   CURRENT_ENERGY_EFFICIENCY      42196 non-null  int64
#  9   POTENTIAL_ENERGY_EFFICIENCY    42196 non-null  int64
#  10  PROPERTY_TYPE                  42196 non-null  object
#  11  BUILT_FORM                     42157 non-null  object
# ...

# %%
# data[data['POSTCODE'].str.contains('ST')==False]

# %%
# data.drop(data[data['POSTCODE'].str.contains('ST')==False].index, inplace=True)
# data1 = data1['POSTCODE']

# %%
data['POSTCODE'].nunique()
data['POSTCODE'].unique()
# Out:
# 2817

# %%
data1 = data['POSTCODE'].unique()
np.savetxt('Postcodes_Newcastle-under-Lyme.csv', data1, delimiter=',', fmt='%s')

# %%
data1 = data.groupby('POSTCODE').agg({'POSTCODE':''})
data1.to_csv('Postcodes_Newcastle-under-Lyme.csv',index=False)
# Out:
#           POSTCODE
# POSTCODE
# CW2 5PY          9
# CW2 5QB          4
# CW2 5QD          6
# CW2 5QE          8
# CW2 5QF          1
# ...            ...
# TF9 4RL          6
# TF9 4RN          8
# TF9 4RP         32
# TF9 4RQ          1
# TF9 4RW         15
#
# [2817 rows x 1 columns]

# %%
data1.nunique()
